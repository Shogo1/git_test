# %%
a=3

# %%
a
# Out:
# 3

# %%
a
# Out:
# 3

# %%
b=10

# %%
b
# Out:
# 10

# %%
a+b
# Out:
# 13

# %%
price = 100

# %%
tax = 0.08

# %%
price * tax
# Out:
# 8.0

# %%
c=10+3

# %%
c
# Out:
# 13

# %%
1a=10
# Out:
#   File "<ipython-input-12-442bddfef1a1>", line 1
#     1a=10
#     ^
# SyntaxError: invalid decimal literal

# %%
1+a=10
# Out:
#   File "<ipython-input-13-24cf27b0f711>", line 1
#     1+a=10
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
a1=10

# %%
a1
# Out:
# 10

# %%
r = 10

# %%
name = '今西'

# %%
name
# Out:
# '今西'

# %%
print(name)
# Out:
# 今西
