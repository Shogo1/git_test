# %%
names=["今西","鈴木","佐藤"]

# %%
names
# Out:
# ['今西', '鈴木', '佐藤']

# %%
type(names)
# Out:
# list

# %%
names[0]
# Out:
# '今西'

# %%
names=["今西","鈴木","佐藤"]

# %%
names[1]
# Out:
# '鈴木'

# %%
scores = [50,80,60]
scores
# Out:
# [50, 80, 60]

# %%
scores[2]
# Out:
# 60

# %%
scores[-1]
# Out:
# 60

# %%
scores[-2]
# Out:
# 80

# %%
scores[0:1]
# Out:
# [50]

# %%
scores[0:2]
# Out:
# [50, 80]

# %%
scores[0:]
# Out:
# [50, 80, 60]

# %%
scores[:-1]
# Out:
# [50, 80]

# %%
scores.append(70)

# %%
scores
# Out:
# [50, 80, 60, 70]

# %%
scores.append(90)

# %%
scores
# Out:
# [50, 80, 60, 70, 90]

# %%
scores.pop()
# Out:
# 90

# %%
scores
# Out:
# [50, 80, 60, 70]

# %%
scores.pop(0)
# Out:
# 50

# %%
scores
# Out:
# [80, 60, 70]

# %%
scores = {"国語":50,"数学":80,"英語":60}

# %%
scores
# Out:
# {'国語': 50, '数学': 80, '英語': 60}

# %%
print(scores)

# %%
scores = {"国語":50,"数学":80,"英語":60}

# %%
scores["国語"]
# Out:
# 50

# %%
scores['理科']=70

# %%
scores
# Out:
# {'国語': 50, '数学': 80, '英語': 60, '理科': 70}

# %%
scores['社会']=100

# %%
scores
# Out:
# {'国語': 50, '数学': 80, '英語': 60, '理科': 70, '社会': 100}

# %%
scores = (10,30,40)

# %%
scores[0]
# Out:
# 10

# %%
scores.append(50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-db310c2866d8> in <cell line: 1>()
# ----> 1 scores.append(50)
#
# AttributeError: 'tuple' object has no attribute 'append'
