# %%
def say_hello():
  print("皆さん、こんにちは。")

# %%
say_hello()
# Out:
# 皆さん、こんにちは。

# %%
say_hello()
# Out:
# 皆さん、こんにちは。

# %%
def say_hello2(name):
  print("{}さん、こんにちは。".format(name))

# %%
say_hello2("デスマンコ膣太郎")
# Out:
# デスマンコ膣太郎さん、こんにちは。

# %%
def say_hello2(name):
  print("{}さん、こんにちは。".format(name))

# %%
say_hello2("デスマンコ膣太郎")
# Out:
# デスマンコ膣太郎さん、こんにちは。

# %%
def calc_square(side):
  return side*side

# %%
result = calc_square(10)

# %%
result
# Out:
# 100

# %%
result=calc_square(50)

# %%
result
# Out:
# 2500

# %%
def calc_try(down_side,anothor_side):
  return (down_side*anothor_side)/2

# %%
result = calc_try(2,3)
result
# Out:
# 3.0

# %%
base = 10
height = 20
area = base*height*0.5
print("面積:",area)
# Out:
# 面積: 100.0

# %%
def calc_try(base,height):
  return base*height*0.5

# %%
calc_try(10,1000)
# Out:
# 5000.0

# %%
def calc_try(base=10,height=10):
  return base*height*0.5

# %%
calc_try(10,1000)
# Out:
# 5000.0

# %%
calc_try()
# Out:
# 50.0
