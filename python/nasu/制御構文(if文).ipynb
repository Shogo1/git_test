# %%
money = 2000

# %%
if money >= 2000:
  print('映画館にいきます')
# Out:
# 映画館にいきます

# %%
if money >= 2000:
  print('映画館にいきます')
else:
    print('映画館には行きません')
# Out:
# 映画館には行きません

# %%
if money >= 8000:
  print('ディズニーランドに行く')
elif money >= 2000:
 print('映画館にいきます')
else:
  print('どこにもいきません')
# Out:
# 映画館にいきます
