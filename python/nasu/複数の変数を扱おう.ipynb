# %%
names = ['那須','鈴木','佐藤']
names
# Out:
# ['那須', '鈴木', '佐藤']

# %%
type(names)
# Out:
# list

# %%
names[0]
# Out:
# '那須'

# %%
scores = [50,80,60]
scores
# Out:
# [50, 80, 60]

# %%
scores[2]
# Out:
# 60

# %%
scores[-1]
# Out:
# 60

# %%
scores[-2]
# Out:
# 80

# %%
scores[0:2]
# Out:
# [50, 80]

# %%
scores[0:]
# Out:
# [50, 80, 60]

# %%
scores.append(70)

# %%
scores
# Out:
# [50, 80, 60, 70]

# %%
scores.append(90)

# %%
scores.pop()
# Out:
# 90

# %%
scores
# Out:
# [50, 80, 60, 70]

# %%
scores.pop(0)
# Out:
# 50

# %%
scores
# Out:
# [80, 60, 70]

# %%
scores = {'国語':50,'数学':80,'英語':60}

# %%
scores['国語']
# Out:
# 50

# %%
scores['数学']
# Out:
# 80

# %%
scores['理科'] = 70

# %%
scores['社会'] = 100

# %%
scores
# Out:
# {'国語': 50, '数学': 80, '英語': 60, '理科': 70, '社会': 100}
