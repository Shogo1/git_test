# %%
def say_something():
  message='こんにちは、私は那須です。'
  print(message)

# %%
say_something()
# Out:
# こんにちは、私は那須です。

# %%
message1 = 'こんにちは、私は那須です。'

# %%
def say_something1():
  print(message1)

# %%
say_something1()
# Out:
# こんにちは、私は那須です。
