# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
from datetime import date

# %%
date.today()
# Out:
# datetime.date(2023, 6, 20)

# %%
date.today().year
# Out:
# 2023

# %%
date.today().month
# Out:
# 6
