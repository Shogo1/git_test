# %%
10+2
# Out:
# 12

# %%
111+222
# Out:
# 333

# %%
10-4
# Out:
# 6

# %%
10-20
# Out:
# -10

# %%
10*10
# Out:
# 100

# %%
1800/100
# Out:
# 18.0

# %%
(100+300)/4
# Out:
# 100.0

# %%
2**3
# Out:
# 8
