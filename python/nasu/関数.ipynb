# %%
def say_hello():
 print('みなさん、こんにちは')

# %%
say_hello()
# Out:
# みなさん、こんにちは

# %%
def say_hello2(name):
 print(name +'さん、こんにちは')

# %%
say_hello2('那須')
# Out:
# 那須さん、こんにちは

# %%
def say_hello2(name):
 print('{}さん、こんにちは'.format(name))

# %%
say_hello2('那須')
# Out:
# 那須さん、こんにちは

# %%
def calc_square(side):
  return side*side

# %%
result = calc_square(10)

# %%
result
# Out:
# 100

# %%
result = calc_square(50)

# %%
def calc_tri(bese,height):
  return (bese*height)/2

# %%
result = calc_tri(10,20)
print(result)
# Out:
# 100.0

# %%
def calc_tri(bese=10,height=20):
  return (bese*height)/2
