# %%
1<3
# Out:
# True

# %%
1>3
# Out:
# False

# %%
1>-1
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
1 == 2
# Out:
# False

# %%
1 != 2
# Out:
# True

# %%
'那須' == '那須'
# Out:
# True

# %%
'那須' == 'nasu'
# Out:
# False
