# %%
a = 120

# %%
type(a)
# Out:
# int

# %%
type(100)
# Out:
# int

# %%
b = 4.5

# %%
type(b)
# Out:
# float

# %%
complex = 3j

# %%
type(complex)
# Out:
# complex

# %%
name ='那須'

# %%
type(name)
# Out:
# str

# %%
fig = True

# %%
type(fig)
# Out:
# bool

# %%
c =[10,20]
c
# Out:
# [10, 20]

# %%
type(c)
# Out:
# list

# %%
d ={}

# %%
type(d)
# Out:
# dict

# %%
e = ()

# %%
type(e)
# Out:
# tuple
