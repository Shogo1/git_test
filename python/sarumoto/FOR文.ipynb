# %%
last_names = ['今西', '佐藤', '鈴木', '高橋','川上']
first_names = ['公平', '陽介', '健司', '健介','順平']
for i in range(len(last_names)):
  print(last_names[i]+first_names[i]+'さん')
# Out:
# 今西公平さん
# 佐藤陽介さん
# 鈴木健司さん
# 高橋健介さん
# 川上順平さん

# %%
for last_name,first_name in zip(last_names,first_names):
  print(last_name+first_name+'さん')
# Out:
# 今西公平さん
# 佐藤陽介さん
# 鈴木健司さん
# 高橋健介さん
# 川上順平さん

# %%
for num,last_name in enumerate(last_names):
  print('出席番号',num,'番目の'+last_name+'さん')
# Out:
# 出席番号 0 番目の今西さん
# 出席番号 1 番目の佐藤さん
# 出席番号 2 番目の鈴木さん
# 出席番号 3 番目の高橋さん
# 出席番号 4 番目の川上さん

# %%
names = ['今西', '佐藤', '鈴木', '高橋','川上']
for i in range(len(names)):
  print(names[i])
# Out:
# 今西
# 佐藤
# 鈴木
# 高橋
# 川上

# %%
a = 0
for i in range(21):
  a=i+a
  print(a)
# Out:
# 0
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 105
# 120
# 136
# 153
# 171
# 190
# 210

# %%
names = ['今西', '佐藤', '鈴木', '高橋','川上']
for name in names:
  print(name+'sann')
# Out:
# 今西sann
# 佐藤sann
# 鈴木sann
# 高橋sann
# 川上sann
