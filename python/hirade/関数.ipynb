# %%
def say_hello():
  print('みなさん、こんにちは。')

# %%
say_hello()
# Out:
# みなさん、こんにちは。

# %%
say_hello()
# Out:
# みなさん、こんにちは。

# %%
def say_hello2(name):
  print('{}さん、みなさん、こんにちは。'.format(name))

# %%
say_hello2('今西')
# Out:
# 今西さん、みなさん、こんにちは。

# %%
say_hello2('佐藤')
# Out:
# 佐藤さん、みなさん、こんにちは。

# %%
def calc_square(side):
  return side * side

# %%
result = calc_square(10)

# %%
result = calc_square(50)

# %%
base = 10
height = 20
area = base * height *0.5
print('面積:', area)
# Out:
# 面積: 100.0

# %%
def calc_tri(base, height):
  return base * height * 0.5

# %%
calc_tri(10,1000)
# Out:
# 5000.0

# %%
def calc_tri(base=10, height=10):
  return base * height * 0.5

# %%
calc_tri(20,50)
# Out:
# 500.0

# %%
calc_tri()
# Out:
# 50.0
