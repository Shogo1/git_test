# %%
def say_something():
  message='こんにちは、私は今西です。'
  print(message)

# %%
say_something()
# Out:
# こんにちは、私は今西です。

# %%
print(message)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-83cfdf559502> in <cell line: 1>()
# ----> 1 print(message)
#
# NameError: name 'message' is not defined

# %%
message1='こんばんは。私は今西です。'

# %%
def say_something1():
  print(message1)

# %%
say_something1()
# Out:
# こんばんは。私は今西です。
